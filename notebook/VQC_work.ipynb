# %%
import os
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold
from sklearn.metrics import roc_auc_score

import pennylane as qml
from pennylane import numpy as pnp

import time

# %%
# Initialize Repeated Stratified K-Fold 
# (2 splits, 30 repeats for statistical robustness)
rskf = RepeatedStratifiedKFold(n_splits=2, n_repeats=30, random_state=42)

auc_scores = []
skipped = 0

# %%
# Set the project directory (Change this to your local qml_project path)
PROJECT_DIR = r"C:\Users\93539\qml_project"
os.chdir(PROJECT_DIR)
print("Current Working Directory (CWD):", os.getcwd())

# Load pre-extracted latent representations and labels
# Z shape typically (N, D), where D is the latent dimension (e.g., 16 or 32)
Z = np.load(r"C:\Users\93539\qml_project\D32\Z_latent_D32.npy")
y = np.load(r"C:\Users\93539\qml_project\D32\y_labels_D32.npy")

print("Z shape:", Z.shape)
print("y shape:", y.shape)
print(f"Positive class rate (Fraud rate): {y.mean():.4f}")

# %%
# =========================================================
# 1) Sampling: N=100, ensuring at least k positive cases
# =========================================================
def stratified_subsample_fixed_pos(Z, y, N=100, min_pos=5, seed=42):
    rng = np.random.default_rng(seed)
    pos_idx = np.where(y == 1)[0]
    neg_idx = np.where(y == 0)[0]

    # Target number of positives: at least min_pos, 
    # while not exceeding N/2 (to avoid extreme imbalance)
    target_pos = max(min_pos, int(round(N * y.mean())))
    target_pos = min(target_pos, N // 2)
    target_pos = min(target_pos, len(pos_idx))
    target_neg = N - target_pos

    # Perform random sampling without replacement for both classes
    sel_pos = rng.choice(pos_idx, size=target_pos, replace=False)
    sel_neg = rng.choice(neg_idx, size=target_neg, replace=False)
    
    # Combine and shuffle the indices
    sel = np.concatenate([sel_pos, sel_neg])
    rng.shuffle(sel)

    return Z[sel], y[sel]

# Execute subsampling
X_small, y_small = stratified_subsample_fixed_pos(Z, y, N=100, min_pos=5, seed=42)

print(f"N: {len(y_small)}")
print(f"Positive cases: {int(y_small.sum())}")
print(f"Positive rate: {y_small.mean():.4f}")

# %%
#Save these samples

np.savez(
    "Xy_small_N100_seed42_d16.npz",
    X=X_small,
    y=y_small
)

print("Saved:", X_small.shape, y_small.shape)


#To read, use the following code
data = np.load("Xy_small_N100_seed42_d16.npz")
X_small = data["X"]
y_small = data["y"]

print("Loaded:", X_small.shape, y_small.shape)
print("pos:", int(y_small.sum()), "pos_rate:", y_small.mean())

# %%
#To read, use the following code
data = np.load("Xy_small_N100D32_seed42.npz")
X_small = data["X"]
y_small = data["y"]

print("Loaded:", X_small.shape, y_small.shape)
print("pos:", int(y_small.sum()), "pos_rate:", y_small.mean())

# %%
# ====== 3) Draw a small sample N (stratified, ensuring the positive case proportion approximates the population)======
N = 200  
rng = np.random.default_rng(42)

pos_idx = np.where(y == 1)[0]
neg_idx = np.where(y == 0)[0]

# Sample positive and negative examples proportionally (ensuring at least 2 positive examples to prevent training failure)
target_pos = max(2, int(round(N * y.mean())))
target_pos = min(target_pos, len(pos_idx))
target_neg = N - target_pos

sel_pos = rng.choice(pos_idx, size=target_pos, replace=False)
sel_neg = rng.choice(neg_idx, size=target_neg, replace=False)
sel = np.concatenate([sel_pos, sel_neg])
rng.shuffle(sel)

X_small = Z[sel]
y_small = y[sel]
print(f"N={len(y_small)}, pos={int(y_small.sum())}, pos_rate={y_small.mean():.4f}")

# %%
# =========================
# 2) Preprocessing: Scale inputs to [-π, π] for angle encoding
# (using training set statistics; performed within each fold)
# =========================
def scale_to_pi(X_train, X_test, eps=1e-8):
    # 标准化 -> tanh 压缩 -> 映射到 [-pi, pi]
    mu = X_train.mean(axis=0, keepdims=True)
    std = X_train.std(axis=0, keepdims=True) + eps
    Xtr = (X_train - mu) / std
    Xte = (X_test - mu) / std

    Xtr = np.tanh(Xtr) * np.pi
    Xte = np.tanh(Xte) * np.pi
    return Xtr, Xte

# %%
# -------------------------
Initialize the shape of weights based on variants
# -------------------------
def init_weights(seed=42):
    rng = np.random.default_rng(seed)
    if "A2" in VARIANT:
        shape = (n_layers, n_qubits, 1)
    elif "A1" in VARIANT:
        shape = (n_layers, n_qubits, 3)
    else:
        shape = (n_layers, n_qubits, 2)
    w0 = 0.01 * rng.standard_normal(size=shape)
    return pnp.array(w0, requires_grad=True)

# %%
def predict_proba(X, weights, bias, w_read=None):
    probs = []
    for i in range(X.shape[0]):
        out = circuit(X[i], weights)

        if isinstance(out, (tuple, list)):
            z = pnp.array(out)  # shape (n_qubits,)

            if (w_read is not None):    # ✅ D2: Trainable weighted readout
                out_scalar = pnp.dot(w_read, z)
            else:                       # ✅ D1: Fixed average readout
                out_scalar = pnp.mean(z)
        else:
            out_scalar = out            # Baseline models: Scalar output

        logit = 2.0 * out_scalar + bias
        probs.append(sigmoid(logit))
    return pnp.array(probs)

def weighted_bce_loss(y_true, y_prob, pos_weight=10.0, eps=1e-8):
    # y_true ∈ {0,1}
    y_true = pnp.array(y_true)
    y_prob = pnp.clip(y_prob, eps, 1 - eps)
    # Binary Cross Entropy with class weighting for imbalanced data
    loss = -(pos_weight * y_true * pnp.log(y_prob) + (1 - y_true) * pnp.log(1 - y_prob))
    return pnp.mean(loss)

def train_vqc(X_train, y_train, steps=50, lr=0.05, seed=42):
    # Initialize trainable readout weights if using Variant D2
    if "D2" in VARIANT:
        w_read = pnp.array(np.zeros(n_qubits), requires_grad=True)  # Init with zeros
    else:
        w_read = None
        
    rng = np.random.default_rng(seed)
    weights = init_weights(seed)
    bias = pnp.array(0.0, requires_grad=True)

    # Calculate class weight based on ratio (neg/pos)
    pos = int(np.sum(y_train))
    neg = len(y_train) - pos
    pos_weight = float(neg / max(pos, 1))  # Standard approach for imbalanced sets

    opt = qml.AdamOptimizer(stepsize=lr)

    def objective(w, b, wr):
        probs = predict_proba(X_train, w, b, wr)
        return weighted_bce_loss(y_train, probs, pos_weight=pos_weight)

    # Optimization loop
    for _ in range(steps):
        if "D2" in VARIANT:
            # Optimize weights, bias, and readout mapping
            weights, bias, w_read = opt.step(objective, weights, bias, w_read)
        else:
            # Optimize only weights and bias (Fixed readout)
            weights, bias = opt.step(lambda w, b: objective(w, b, None), weights, bias)

    return weights, bias, w_read

# %%
# =========================================================
# 3) VQC Structure: 4 qubits + Data Re-uploading 
# (4 dimensions per injection × 4 times = 16 dimensions total)
# =========================================================
n_qubits = 4
n_layers = 1  
dev = qml.device("lightning.qubit", wires=n_qubits)

# -------------------------
# Entanglement Schemes
# -------------------------
def entangle_ring():
    """Full ring entanglement using CNOT gates."""
    for i in range(n_qubits):
        qml.CNOT(wires=[i, (i + 1) % n_qubits])

def entangle_chain():
    """Linear chain entanglement."""
    qml.CNOT(wires=[0, 1])
    qml.CNOT(wires=[1, 2])
    qml.CNOT(wires=[2, 3])

def entangle():
    """Select entanglement based on Variant B1."""
    if "B1" in VARIANT:
        entangle_chain()
    else:
        entangle_ring()

# -------------------------
# Data Embedding (Encoding)
# -------------------------
def embed_block(x4):
    """Injects 4 dimensions of data into the circuit."""
    if "C1" in VARIANT:
        # C1: Stronger embedding using both RY and RZ (phase injection)
        for q in range(n_qubits):
            qml.RY(x4[q], wires=q)
            qml.RZ(x4[q], wires=q)
    else:
        # Baseline: Standard RY embedding
        for q in range(n_qubits):
            qml.RY(x4[q], wires=q)

# -------------------------
# Trainable Block
# Weights shape varies by variant
# -------------------------
def trainable_block(weights, l):
    if "A2" in VARIANT:
        # A2: Stronger regularization using only RY (fewer parameters)
        # weights shape: (n_layers, n_qubits, 1)
        for q in range(n_qubits):
            qml.RY(weights[l, q, 0], wires=q)

    elif "A1" in VARIANT:
        # A1: Higher expressivity using Rot gates (3 parameters per qubit)
        # weights shape: (n_layers, n_qubits, 3)
        for q in range(n_qubits):
            qml.Rot(weights[l, q, 0], weights[l, q, 1], weights[l, q, 2], wires=q)

    else:
        # baseline / B1 / C1 / D1: RY + RZ (2 parameters per qubit)
        # weights shape: (n_layers, n_qubits, 2)
        for q in range(n_qubits):
            qml.RY(weights[l, q, 0], wires=q)
            qml.RZ(weights[l, q, 1], wires=q)

# -------------------------
# Readout (Measurement)
# -------------------------
def readout():
    """Defines the measurement strategy for the final state."""
    if ("D1" in VARIANT) or ("D2" in VARIANT):
        # Return all expectation values as a tuple for weighted processing
        return tuple(qml.expval(qml.PauliZ(i)) for i in range(n_qubits))
    else:
        # Standard: Measure only the first qubit
        return qml.expval(qml.PauliZ(0))

# -------------------------
# Circuit Body: 16D Data Re-uploading
# -------------------------
@qml.qnode(dev, interface="autograd")
def circuit(x, weights):
    # Split 16D (or 32D) input into chunks of 4 to match qubit count
    num_chunks = x.shape[0] // n_qubits  
    
    for l in range(n_layers):
        for chunk in range(num_chunks):
            # Extract 4-dimensional data slice
            xq = x[chunk * n_qubits:(chunk + 1) * n_qubits]
            embed_block(xq)

            # ✅ B2-weak: Only entangle once per layer (on the first chunk)
            if ("B2" in VARIANT) and (chunk != 0):
                pass
            else:
                entangle()

            trainable_block(weights, l)
            
    return readout()

def sigmoid(z):
    """Standard activation function for mapping logits to probabilities."""
    return 1.0 / (1.0 + pnp.exp(-z))

# %%
#A2 (Stronger Regular Expressions / Weaker Injection): RY Injection Only
def feature_map_A2(x16):
    for chunk in range(4):
        x4 = x16[chunk*4:(chunk+1)*4]
        for q in range(n_qubits):
            qml.RY(x4[q], wires=q)
        entangle_ring()

# %%
#A1 (Stronger Expression): Make injection more “Rot-like”
def feature_map_A1(x16):
    for chunk in range(4):
        x4 = x16[chunk*4:(chunk+1)*4]
        for q in range(n_qubits):
            a = x4[q]
            qml.Rot(a, a, a*a, wires=q)
        entangle_ring()

# %%
#B1 (Chain entanglement): Change ring to chain
def entangle_chainB1():
    qml.CNOT(wires=[0,1])
    qml.CNOT(wires=[1,2])
    qml.CNOT(wires=[2,3])

def feature_map_B1(x16):
    for chunk in range(4):
        x4 = x16[chunk*4:(chunk+1)*4]
        for q in range(n_qubits):
            qml.RY(x4[q], wires=q)
            qml.RZ(x4[q], wires=q)
        entangle_chainB1()

def feature_map_A1_B1(x16):
    for chunk in range(4):
        x4 = x16[chunk*4:(chunk+1)*4]
        for q in range(n_qubits):
            a = x4[q]
            qml.Rot(a, a, a*a, wires=q)
        entangle_chainB1()

# %%
#C1 (Enhanced Data Injection): Adding “Quadratic Term Injection” to the baseline
def feature_map_C1(x16):
    for chunk in range(4):
        x4 = x16[chunk*4:(chunk+1)*4]
        for q in range(n_qubits):
            a = x4[q]
            qml.RY(a, wires=q)
            qml.RZ(a, wires=q)
            qml.RY(a*a, wires=q)   
        entangle_ring()

# %%
#D1 (mean(Zi) readout): QSVM lacks a dedicated “readout head,” employing “multi-bit overlap” for approximation.
def quantum_kernel_D1(x1, x2):
    probs = kernel_circuit(x1, x2)  # length 2^n_qubits
    # parity-even states: indices with even number of 1s
    total = 0.0
    for idx, p in enumerate(probs):
        if bin(idx).count("1") % 2 == 0:
            total += p
    return float(total)

# %%
# ========= Configuration: Variants to Run =========
# Options: "baseline", "A2", "A1", "B1", "C1", "D1", "B1+C1", 
# "B1+D1", "B1+C1+D1", "B1+D1+B2", "B1+D2", "B1+D2+B2"
variants = ["baseline"]

# ========= Configuration: CV Random Seeds =========
cv_seeds = [42]

# ========= Result Container =========
all_rows = []

t_start = time.time()

for VARIANT in variants:
    print("\n" + "="*30)
    print(f"Running VARIANT: {VARIANT}")
    print("="*30)

    for cv_seed in cv_seeds:
        print(f"\n--- CV seed = {cv_seed} ---")

        # Define Repeated Stratified K-Fold for robust evaluation
        rskf = RepeatedStratifiedKFold(
            n_splits=2,
            n_repeats=30,
            random_state=cv_seed
        )

        auc_scores = []
        skipped = 0

        for fold_id, (train_idx, test_idx) in enumerate(rskf.split(X_small, y_small), 1):
            X_train_raw, X_test_raw = X_small[train_idx], X_small[test_idx]
            y_train, y_test = y_small[train_idx], y_small[test_idx]

            # Safety check: ensure both classes are present in the fold
            if len(np.unique(y_train)) < 2 or len(np.unique(y_test)) < 2:
                skipped += 1
                continue

            # Scale features to [-pi, pi] within the fold to prevent data leakage
            X_train, X_test = scale_to_pi(X_train_raw, X_test_raw)

            # Training: train_vqc returns (weights, bias, w_read)
            # Use fold_id to ensure different but reproducible initializations
            weights, bias, w_read = train_vqc(
                X_train, y_train,
                steps=30,
                lr=0.05,
                seed=1000 * cv_seed + fold_id
            )

            # Prediction and AUC
