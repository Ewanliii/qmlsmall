# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# %%
# 1. Read a subset of data (avoid loading everything at once)
# =========================================================

DATA_PATH = r"C:\Users\93539\train_transaction.csv"

# Only read the first few rows to speed up initial processing 
# (Note: Stratified sampling will be performed later)
df = pd.read_csv(DATA_PATH)

overall_fraud_rate = df["isFraud"].mean()
print(f"Overall fraud rate (full dataset): {overall_fraud_rate:.4f}")

# %%
# 2. Labels
y = df["isFraud"]

# Keep only numerical features (exclude categorical variables like card type / card network)
X = df.select_dtypes(include=[np.number]).drop(columns=["isFraud"])

print("Original feature dimension:", X.shape[1])

# %%
# 3. Missing value imputation
imputer = SimpleImputer(strategy="median")
X_imp = imputer.fit_transform(X)

# Feature scaling (Standardization)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imp)

# Convert to PyTorch tensors
X_tensor = torch.tensor(X_scaled, dtype=torch.float32)

# %%
# 4、built Denoising Autoencoder
class DAE(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super().__init__()

        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, latent_dim)
        )

        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, input_dim)
        )

    def forward(self, x):
        z = self.encoder(x)
        x_recon = self.decoder(z)
        return x_recon

# %%
# 5. Train DAE (Applying "Denoising")

# Noise: Gaussian noise
# Noise intensity: noise_std = 0.1 (Conservative and safe)
# Loss function: MSE
# Note: Validation set is not required (this is pre-training)


# Hyperparameters
input_dim = X_tensor.shape[1]
latent_dim = 32          # ← Can be adjusted later
batch_size = 1024
num_epochs = 20
learning_rate = 1e-3
noise_std = 0.1

# Data Loading
dataset = TensorDataset(X_tensor)
loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Model Initialization
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DAE(input_dim, latent_dim).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.MSELoss()

# Training Loop
model.train()
for epoch in range(num_epochs):
    total_loss = 0.0
    for (x_batch,) in loader:
        x_batch = x_batch.to(device)

        # Inject noise
        noise = noise_std * torch.randn_like(x_batch)
        x_noisy = x_batch + noise

        # Forward pass
        x_recon = model(x_noisy)
        loss = criterion(x_recon, x_batch)

        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * x_batch.size(0)

    avg_loss = total_loss / len(dataset)
    print(f"Epoch [{epoch+1}/{num_epochs}] - Recon Loss: {avg_loss:.6f}")

# %%
# 6. Extract latent representations
model.eval()
with torch.no_grad():
    Z = model.encoder(X_tensor.to(device)).cpu().numpy()

print("Latent representation shape:", Z.shape)

# %%
import joblib

np.save("Z_latent_D16.npy", Z)
np.save("y_labels.npy", y.values)
torch.save(model.encoder.state_dict(), "dae_encoder_D16.pt")
joblib.dump(imputer, "imputer.joblib")
joblib.dump(scaler, "scaler.joblib")

# %%
import os
files = [
    "Z_latent_D16.npy",
    "y_labels.npy",
    "dae_encoder_D16.pt",
    "imputer.joblib",
    "scaler.joblib",
]

for f in files:
    print(f, "exists:", os.path.exists(f))
